# %% [markdown]
# ### Lesson 07.11.2025

# %%
shopping = ["bread", "potatoes", "milk", "soap", "beer", "butter", "apples", "dumplings", "fish", "backing powder", "eggs"]

# %%
shopping.sort()

# %%
shopping
# Out:
# ['apples',
#  'backing powder',
#  'beer',
#  'bread',
#  'butter',
#  'dumplings',
#  'eggs',
#  'fish',
#  'milk',
#  'potatoes',
#  'soap']

# %%
shopping.append("cheese")

# %%
shopping
# Out:
# ['apples',
#  'backing powder',
#  'beer',
#  'bread',
#  'butter',
#  'dumplings',
#  'eggs',
#  'fish',
#  'milk',
#  'potatoes',
#  'soap',
#  'cheese']

# %%
shopping.insert(0 , "juice")

# %%
shopping.pop()
# takes the last item of the list and takes it out
# Out:
# 'cheese'

# %%
s ="The sleepy duck is lazy and the fatigued snack too."
words = s.split()
words
# Out:
# ['The',
#  'sleepy',
#  'duck',
#  'is',
#  'lazy',
#  'and',
#  'the',
#  'fatigued',
#  'snack',
#  'too.']

# %%
# 2nd letter 4th word
words[3][1]
# Out:
# 's'

# %%
# sometimes it usefull to make an empty list at the beginning just to later fill it with values
empty = []
type(empty)
# Out:
# list

# %%
values = []
values.append(1)
values.append(3)
values.append(5)
print('first time:', values)
values = values[1:] # forgot to index with the double dot
print('second time:', values)
# Out:
# first time: [1, 3, 5]
# second time: [3, 5]

# %%
start = 10
stop = 20
values = s
print(values)
values[start:stop]
# Out:
# The sleepy duck is lazy and the fatigued snack too.
# ' duck is l'

# %%
s_ ="_".join(words) #joins the substrings with the given charachter
s_
# Out:
# 'The_sleepy_duck_is_lazy_and_the_fatigued_snack_too.'

# %%
help(s.join)
# Out:
# Help on built-in function join:
#
# join(iterable, /) method of builtins.str instance
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
