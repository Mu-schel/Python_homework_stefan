# %% [markdown]
# Rosalind HAMM
#
# --------
#
# finding sequence differences between two given strings

# %%
a = "..." 
b = "..."

# %%
def find_mismatches(seq1, seq2):
    mismatches = []
    for i in range(min(len(seq1), len(seq2))):
        if seq1[i] != seq2[i]:
            mismatches.append((i, seq1[i], seq2[i]))
    return mismatches

# %%
count_mismatches = len(find_mismatches(a, b))
print("Hamm distance is:", count_mismatches)
# Out:
# Hamm distance is: 7
