# %% [markdown]
# ### Rosalind REVP
#
# finding all restriction sites in a sequence
#
# given a string of at most 1 kb length
#
# return all restriction sites, which are reverse palindroms
#
# -----------------

# %%
import util

# %%
lines = util.read_file_into_lines("/home/uschi/Python_homework_stefan/misc/rosalind_revp.txt")
# sequences = util.parse_fasta(lines)
