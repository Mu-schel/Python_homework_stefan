# %% [markdown]
# ### Rosalind subs
# -----------------------------
# Finding out at any which position of a string a substring motiv occurs.
#
# ------------------------------

# %%
import util

# %%
#file_lines = util.read_file_into_lines("/home/uschi/Python_homework_stefan/misc/rosalind_subs.txt")
#sequences = util.parse_fasta(file_lines)

# %%
s = "GATATATGCATATACTT"
t = "ATAT"

if s[1] == t[0]:
    print("yes")
else:
    print("no")
# Out:
# yes
