# %%
battery_bays = [
"987654321111111",
"811111111111119",
"234234234234278",
"818181911112111",
]

# %%
battery_bays = "987654321111111"

# %%
max_sofar = 0
max_index = -1
for i, x in enumerate(battery_bays[0:-1]):
    if int(x) > max_sofar:
        max_sofar = int(x)
        max_index = i
        print(max_index)
        print(max_sofar)
# Out:
# 0
# 9
