# %% [markdown]
# # Lesson
# ### 12.11.2025 if else, conditionals, loops

# %% [markdown]
# If/else statement for checking if a variable Fruit is a banana.

# %%
fruite = "Bannana"
if fruite == "Bannana":
    print("This is a Bannana.")
else:
    print("This is not a Bannana.")
# Out:
# This is a Bannana.

# %% [markdown]
# Rosalind INI4, adding up all odd numbers between two integers.

# %%
a = 4217
b = 8740
result = 0
for n in range(a, b+1):
    if n % 2 == 1:
        result =  result + n
print(result)
# Out:
# 14653236

# %% [markdown]
# Rosalind INI6 given a string s, print all words and their frequency.
