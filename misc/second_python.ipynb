# %%
b = .5
print(type(b))
# Out:
# <class 'float'>

# %%
a = 4
print(type(b))
# Out:
# <class 'int'>

# %%
d =  3-2
print(type(b))
# Out:
# <class 'int'>

# %%
c = "Art"
type(c)
# Out:
# str

# %%
f = "hello" + "h"
print(type(f))
# Out:
# <class 'str'>

# %%
len(f)
# Out:
# 6

# %%
test = "test test test test"
test.replace("e" , "a")

# %%
s = "..."
count_A = s.count("A")
count_C = s.count("C")
count_G = s.count("G")
count_T = s.count("T")
print(count_A , count_C , count_G , count_T)
# Out:
# 229 252 261 248

# %%
type(3.25 + 4)
# Out:
# float
