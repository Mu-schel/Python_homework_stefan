# %%
import util

# %%
List_test = util.read_file_into_lines("/home/uschi/Python_homework_stefan/misc/AOC2025_1_input.txt")

# %%
# List_test

# %%
List_test= [
"L68",
"L30",
"R48",
"L5",
"R60",
"L55",
"L1",
"L99",
"R14",
"L82",
]

# %%
# this function goes through the list of moves (left or right)
# from the starting position and returns a list of positions after each move
# works if there are only up to three digits in the 
# items in the list must have the format "RXXX" or "LXXX"

# def find_positions (List_of_moves , start_position):
#     pos = start_position
#     position_result = []
# 
#     for item in List_of_moves:
#         if item[0] == 'R' and int(item[1:]) >= 100:
#             pos += (int(item[1:])-((int(item[1])) * 100))
#             if pos >= 100:
#                 pos -= 100
#             position_result.append(pos)
#         elif item[0] == 'L' and int(item[1:]) >= 100:
#             pos -= (int(item[1:])-((int(item[1])) * 100))
#             if pos < 0:
#                 pos += 100
#             position_result.append(pos)
#         elif item[0] == 'R' and int(item[1:]) < 100:
#             pos += int(item[1:])
#             if pos >= 100:
#                 pos -= 100
#             position_result.append(pos)
#         elif item[0] == 'L' and int(item[1:]) < 100:
#             pos -= int(item[1:])
#             if pos < 0:
#                 pos += 100
#             position_result.append(pos)
#     return position_result

# %%
# def find_positions (List_of_moves , start_position):
pos = 50
position_result = []
for item in List_test:
    if item[0] == 'R' and int(item[1:]) >= 100:
        pos += (int(item[1:])-((int(item[1])) * 100))
        if pos >= 100:
            pos -= 100
            #position_result.append("0R1")
        position_result.append(pos)
    elif item[0] == 'L' and int(item[1:]) >= 100:
        pos -= (int(item[1:])-((int(item[1])) * 100))
        if pos < 0:
            pos += 100
            position_result.append("0L1")
        position_result.append(pos)
        #(position_result.append(0))*(int(item[1]))
    elif item[0] == 'R' and int(item[1:]) < 100:
        pos += int(item[1:])
        if pos >= 100:
            pos -= 100
            #position_result.append("0R2")
        position_result.append(pos)
    elif item[0] == 'L' and int(item[1:]) < 100:
        pos -= int(item[1:])
        if pos < 0:
            pos += 100
            #position_result.append("0L2")
        position_result.append(pos)
print(position_result)
# Out:
# [82, 52, 0, 95, 55, 0, 99, 0, 14, 32]

# %%
position_result_list = find_positions(List_test , 50)

# %%
secret_key = 0
for position in position_result_list:
    if position == 0:
        secret_key += 1
print(secret_key)
# Out:
# 1066
