# %%
List_test= [
"L68",
"L30",
"R48",
"L5",
"R60",
"L55",
"L1",
"L99",
"R14",
"L382",
]

# %%
#def find_position (List_rotations, startposition):
pos = 50

for item in List_test:
    if item[0] == 'R':
        pos = pos + int(item[1:])
        if pos >= 100:
            pos = pos - 100
        print(pos)
    elif item[0] == 'L':
        pos = pos - int(item[1:])
        if pos < 0:
            pos = pos + 100
        print(pos)
# Out:
# 82
# 52
# 0
# 95
# 55
# 0
# 99
# 0
# 14
# -268
