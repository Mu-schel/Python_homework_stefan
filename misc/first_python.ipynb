# %% [markdown]
# # First steps with python
#
# Comment it later ...

# %%
print("Hello world.")
# Out:
# Hello world.

# %% [markdown]
# ## math operators

# %%
10 % 3 
# modulo opperator, shows leftover from the devision
# Out:
# 1

# %%
2**50 # double star for 'to the power of ...'
# Out:
# 1125899906842624

# %% [markdown]
# ## other operators

# %%
8 * "Hi "
# Out:
# 'Hi Hi Hi Hi Hi Hi Hi Hi '

# %%
x = 3
print(x)
# Out:
# 3

# %%
y = (10 / 7)
print(x , y)
# Out:
# 3 1.4285714285714286

# %%
s = "The quick brown fox jumps over the lazy dog."
s
# Out:
# 'The quick brown fox jumps over the lazy dog.'

# %%
s.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG.'

# %%
s.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog.'

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog.'

# %%
s.count('the')
# Out:
# 1

# %%
s.lower().count('the')
# Out:
# 2

# %%
s.capitalize()
# Out:
# 'The quick brown fox jumps over the lazy dog.'

# %%
# help(function) to get more info

# %%
s.split() # create a list of substrings cutting at the space
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']

# %%
# yyyy-mm-dd_<name> 
# iso format for saving files

# %%
a = 934
b = 853
c = a**2 + b**2
print(c)
# Out:
# 1599965

# %%
x = "Z9m2cYoA78CfZvg9EFjPTgdbPjZV1yiwiDimTeMec9BmQAIWA6Nbta26yzPoWSlAJWlLSzI1E0P77gqOKordrhYHBLJqXMargaritiferaZVNWZsTUintermediaQ2qcN0a8swF9hHUpVtsH4gD2ZnK8TGc1Mt0jXBYkM4mNEpSmRjbbgs9ZjTBMT6SLcJwO9"
print(x[93:106] , x[114:124])
# Out:
# Margaritifera intermedia

# %%
8^3
# Out:
# 11
